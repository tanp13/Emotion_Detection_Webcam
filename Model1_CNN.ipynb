# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import tensorflow.keras.backend as K

# Parameters
IMAGE_SHAPE = (64, 64)  # Update based on your image dimensions
BATCH_SIZE = 32
test_dir = "FER2013/test"
train_dir = "FER2013/train"

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# Load Data
print("training_data")
training_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                   label_mode="categorical",
                                                                   image_size=IMAGE_SHAPE,
                                                                   batch_size=BATCH_SIZE)

print("testing_data")
testing_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                   label_mode="categorical",
                                                                   image_size=IMAGE_SHAPE,
                                                                   batch_size=BATCH_SIZE,
                                                                   shuffle=False)

# Model Architecture
no_of_classes = 7

model_1 = Sequential()

# 1st Convolutional Layer
model_1.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', input_shape=(64, 64, 3)))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 2nd Convolutional Layer
model_1.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 3rd Convolutional Layer
model_1.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 4th Convolutional Layer
model_1.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 5th Convolutional Layer
model_1.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# Global Average Pooling
model_1.add(GlobalAveragePooling2D())

# 1st Fully Connected Layer
model_1.add(Dense(256, kernel_regularizer=l2(0.001)))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))

# 2nd Fully Connected Layer
model_1.add(Dense(512, kernel_regularizer=l2(0.001)))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))

# Output Layer
model_1.add(Dense(no_of_classes, activation='softmax'))

# Compile the model with SGD optimizer and categorical crossentropy loss
opt = SGD(learning_rate=0.01, momentum=0.9)
model_1.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Model summary to view the architecture
model_1.summary()

# Callbacks
checkpoint = ModelCheckpoint("./model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, mode='auto', restore_best_weights=True)
reduce_learningrate = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_delta=0.0001)

# Learning rate scheduler
def lr_schedule(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return float(K.eval(lr * tf.math.exp(-0.1)))

lr_scheduler = LearningRateScheduler(lr_schedule)

callbacks_list = [early_stopping, checkpoint, reduce_learningrate, lr_scheduler]

# Training
history_1 = model_1.fit(training_data,
                       epochs=10,
                       validation_data=testing_data,
                       callbacks=callbacks_list)

# Fine-tuning
final_epoch = 25
history_2 = model_1.fit(training_data,
                        epochs=final_epoch,
                        validation_data=testing_data,
                        callbacks=callbacks_list,
                        initial_epoch=history_1.epoch[-1])

# Comparison Function
def compare_historys(original_history, new_history, initial_epochs=10):
    acc = original_history.history["accuracy"]
    loss = original_history.history["loss"]
    val_acc = original_history.history["val_accuracy"]
    val_loss = original_history.history["val_loss"]

    total_acc = acc + new_history.history["accuracy"]
    total_loss = loss + new_history.history["loss"]
    total_val_acc = val_acc + new_history.history["val_accuracy"]
    total_val_loss = val_loss + new_history.history["val_loss"]

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(total_acc, label='Training Accuracy')
    plt.plot(total_val_acc, label='Validation Accuracy')
    plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(total_loss, label='Training Loss')
    plt.plot(total_val_loss, label='Validation Loss')
    plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()
# Out:
# training_data
# Found 28709 files belonging to 7 classes.
# testing_data
# Found 7178 files belonging to 7 classes.
# C:\Users\Tanisha\anaconda3\envs\env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 2, 2, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 2, 2, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 1, 1, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 1, 1, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,315,847 (5.02 MB)
#  Trainable params: 1,312,647 (5.01 MB)
#  Non-trainable params: 3,200 (12.50 KB)
# Epoch 1/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.2001 - loss: 2.8034
# Epoch 1: val_accuracy improved from -inf to 0.21566, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 167s 179ms/step - accuracy: 0.2001 - loss: 2.8032 - val_accuracy: 0.2157 - val_loss: 2.3212 - learning_rate: 0.0100
# Epoch 2/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2408 - loss: 2.3251
# Epoch 2: val_accuracy improved from 0.21566 to 0.27988, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 114s 127ms/step - accuracy: 0.2409 - loss: 2.3249 - val_accuracy: 0.2799 - val_loss: 2.1420 - learning_rate: 0.0100
# Epoch 3/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.2722 - loss: 2.1202
# Epoch 3: val_accuracy did not improve from 0.27988
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 114ms/step - accuracy: 0.2722 - loss: 2.1200 - val_accuracy: 0.2731 - val_loss: 2.0877 - learning_rate: 0.0100
# Epoch 4/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3121 - loss: 1.9559
# Epoch 4: val_accuracy improved from 0.27988 to 0.35790, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 97s 108ms/step - accuracy: 0.3121 - loss: 1.9558 - val_accuracy: 0.3579 - val_loss: 1.8392 - learning_rate: 0.0100
# Epoch 5/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3422 - loss: 1.8359
# Epoch 5: val_accuracy did not improve from 0.35790
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 115ms/step - accuracy: 0.3422 - loss: 1.8359 - val_accuracy: 0.3550 - val_loss: 1.8158 - learning_rate: 0.0100
# Epoch 6/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3609 - loss: 1.7640
# Epoch 6: val_accuracy improved from 0.35790 to 0.38771, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 116ms/step - accuracy: 0.3609 - loss: 1.7640 - val_accuracy: 0.3877 - val_loss: 1.6886 - learning_rate: 0.0100
# Epoch 7/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3752 - loss: 1.6990
# Epoch 7: val_accuracy did not improve from 0.38771
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 106s 118ms/step - accuracy: 0.3752 - loss: 1.6990 - val_accuracy: 0.3873 - val_loss: 1.6926 - learning_rate: 0.0100
# Epoch 8/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3790 - loss: 1.6684
# Epoch 8: val_accuracy improved from 0.38771 to 0.42407, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 105s 117ms/step - accuracy: 0.3790 - loss: 1.6684 - val_accuracy: 0.4241 - val_loss: 1.5610 - learning_rate: 0.0100
# Epoch 9/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3923 - loss: 1.6272
# Epoch 9: val_accuracy improved from 0.42407 to 0.42909, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 100s 111ms/step - accuracy: 0.3923 - loss: 1.6271 - val_accuracy: 0.4291 - val_loss: 1.5385 - learning_rate: 0.0100
# Epoch 10/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4052 - loss: 1.5982
# Epoch 10: val_accuracy did not improve from 0.42909
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 114ms/step - accuracy: 0.4052 - loss: 1.5982 - val_accuracy: 0.4244 - val_loss: 1.5284 - learning_rate: 0.0100
# Restoring model weights from the end of the best epoch: 10.
# Epoch 10/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4095 - loss: 1.5836
# Epoch 10: val_accuracy improved from 0.42909 to 0.45152, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 107s 119ms/step - accuracy: 0.4095 - loss: 1.5836 - val_accuracy: 0.4515 - val_loss: 1.4698 - learning_rate: 0.0100
# Epoch 11/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4141 - loss: 1.5583
# Epoch 11: val_accuracy improved from 0.45152 to 0.45556, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 133s 148ms/step - accuracy: 0.4141 - loss: 1.5583 - val_accuracy: 0.4556 - val_loss: 1.4545 - learning_rate: 0.0090
# Epoch 12/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.4306 - loss: 1.5317
# Epoch 12: val_accuracy did not improve from 0.45556
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 145s 161ms/step - accuracy: 0.4306 - loss: 1.5317 - val_accuracy: 0.4324 - val_loss: 1.5258 - learning_rate: 0.0082
# Epoch 13/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4335 - loss: 1.5161
# Epoch 13: val_accuracy did not improve from 0.45556
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.4335 - loss: 1.5161 - val_accuracy: 0.4556 - val_loss: 1.4539 - learning_rate: 0.0074
# Epoch 14/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4367 - loss: 1.4919
# Epoch 14: val_accuracy improved from 0.45556 to 0.47144, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.4367 - loss: 1.4919 - val_accuracy: 0.4714 - val_loss: 1.4105 - learning_rate: 0.0067
# Epoch 15/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4458 - loss: 1.4790
# Epoch 15: val_accuracy did not improve from 0.47144
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 112ms/step - accuracy: 0.4458 - loss: 1.4790 - val_accuracy: 0.4543 - val_loss: 1.4338 - learning_rate: 0.0061
# Epoch 16/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4508 - loss: 1.4695
# Epoch 16: val_accuracy did not improve from 0.47144
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 114ms/step - accuracy: 0.4508 - loss: 1.4695 - val_accuracy: 0.4714 - val_loss: 1.4006 - learning_rate: 0.0055
# Epoch 17/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4603 - loss: 1.4460
# Epoch 17: val_accuracy improved from 0.47144 to 0.48621, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 114ms/step - accuracy: 0.4603 - loss: 1.4460 - val_accuracy: 0.4862 - val_loss: 1.3577 - learning_rate: 0.0050
# Epoch 18/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4589 - loss: 1.4423
# Epoch 18: val_accuracy did not improve from 0.48621
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 110s 123ms/step - accuracy: 0.4589 - loss: 1.4423 - val_accuracy: 0.4850 - val_loss: 1.3702 - learning_rate: 0.0045
# Epoch 19/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4639 - loss: 1.4404
# Epoch 19: val_accuracy improved from 0.48621 to 0.49248, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 115ms/step - accuracy: 0.4639 - loss: 1.4404 - val_accuracy: 0.4925 - val_loss: 1.3686 - learning_rate: 0.0041
# Epoch 20/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4668 - loss: 1.4179
# Epoch 20: val_accuracy improved from 0.49248 to 0.49833, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 105s 117ms/step - accuracy: 0.4668 - loss: 1.4179 - val_accuracy: 0.4983 - val_loss: 1.3245 - learning_rate: 0.0037
# Epoch 21/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4678 - loss: 1.4110
# Epoch 21: val_accuracy did not improve from 0.49833
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 115ms/step - accuracy: 0.4678 - loss: 1.4109 - val_accuracy: 0.4880 - val_loss: 1.3603 - learning_rate: 0.0033
# Epoch 22/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4777 - loss: 1.3957
# Epoch 22: val_accuracy improved from 0.49833 to 0.50613, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 114ms/step - accuracy: 0.4777 - loss: 1.3957 - val_accuracy: 0.5061 - val_loss: 1.3157 - learning_rate: 0.0030
# Epoch 23/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4764 - loss: 1.3942
# Epoch 23: val_accuracy did not improve from 0.50613
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 114ms/step - accuracy: 0.4764 - loss: 1.3941 - val_accuracy: 0.5042 - val_loss: 1.3085 - learning_rate: 0.0027
# Epoch 24/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4806 - loss: 1.3831
# Epoch 24: val_accuracy improved from 0.50613 to 0.50641, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 114ms/step - accuracy: 0.4806 - loss: 1.3831 - val_accuracy: 0.5064 - val_loss: 1.3047 - learning_rate: 0.0025
# Epoch 25/25
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4828 - loss: 1.3693
# Epoch 25: val_accuracy improved from 0.50641 to 0.50961, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 116ms/step - accuracy: 0.4828 - loss: 1.3693 - val_accuracy: 0.5096 - val_loss: 1.3030 - learning_rate: 0.0022
# Restoring model weights from the end of the best epoch: 25.

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Conv2D, BatchNormalization, Activation, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import tensorflow.keras.backend as K

# %%
test_dir = "FER2013/test"
train_dir = "FER2013/train"

IMAGE_SHAPE = (64,64)
BATCH_SIZE = 32

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# Load Data
print("training_data")
training_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                   label_mode="categorical",
                                                                   image_size=IMAGE_SHAPE,
                                                                   batch_size=BATCH_SIZE)

print("testing_data")
testing_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                   label_mode="categorical",
                                                                   image_size=IMAGE_SHAPE,
                                                                   batch_size=BATCH_SIZE,
                                                                   shuffle=False)
# Out:
# training_data
# Found 28709 files belonging to 7 classes.
# testing_data
# Found 7178 files belonging to 7 classes.

# %%
# Model Architecture
no_of_classes = 7

model_1 = Sequential()

# 1st Convolutional Layer
model_1.add(Conv2D(64, (3, 3), strides=(2, 2), padding='same', input_shape=(64, 64, 3)))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 2nd Convolutional Layer
model_1.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 3rd Convolutional Layer
model_1.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 4th Convolutional Layer
model_1.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# 5th Convolutional Layer
model_1.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model_1.add(Dropout(0.25))

# Global Average Pooling
model_1.add(GlobalAveragePooling2D())

# 1st Fully Connected Layer
model_1.add(Dense(256, kernel_regularizer=l2(0.001)))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))

# 2nd Fully Connected Layer
model_1.add(Dense(512, kernel_regularizer=l2(0.001)))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(Dropout(0.5))

# Output Layer
model_1.add(Dense(no_of_classes, activation='softmax'))

# Compile the model with SGD optimizer and categorical crossentropy loss
opt = SGD(learning_rate=0.01, momentum=0.9)
model_1.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Model summary to view the architecture
model_1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)                    │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 2, 2, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 2, 2, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_9 (Activation)            │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 1, 1, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_10 (Activation)           │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 1, 1, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 1, 1, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_11 (Activation)           │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 1, 1, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_12 (Activation)           │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_13 (Activation)           │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,315,847 (5.02 MB)
#  Trainable params: 1,312,647 (5.01 MB)
#  Non-trainable params: 3,200 (12.50 KB)

# %%
# Callbacks
checkpoint = ModelCheckpoint("./model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, mode='auto', restore_best_weights=True)
reduce_learningrate = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_delta=0.0001)

# Learning rate scheduler
def lr_schedule(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return float(K.eval(lr * tf.math.exp(-0.1)))

lr_scheduler = LearningRateScheduler(lr_schedule)

callbacks_list = [early_stopping, checkpoint, reduce_learningrate, lr_scheduler]

# %%
# Training
history_1 = model_1.fit(training_data,
                       epochs=10,
                       validation_data=testing_data,
                       callbacks=callbacks_list)

# Fine-tuning
final_epoch = 35
history_2 = model_1.fit(training_data,
                        epochs=final_epoch,
                        validation_data=testing_data,
                        callbacks=callbacks_list,
                        initial_epoch=history_1.epoch[-1])
# Out:
# Epoch 1/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.2008 - loss: 2.7812
# Epoch 1: val_accuracy improved from -inf to 0.21649, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 145s 155ms/step - accuracy: 0.2008 - loss: 2.7809 - val_accuracy: 0.2165 - val_loss: 2.3131 - learning_rate: 0.0100
# Epoch 2/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.2325 - loss: 2.3598
# Epoch 2: val_accuracy improved from 0.21649 to 0.25397, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 100s 111ms/step - accuracy: 0.2325 - loss: 2.3597 - val_accuracy: 0.2540 - val_loss: 2.1419 - learning_rate: 0.0100
# Epoch 3/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.2540 - loss: 2.1406
# Epoch 3: val_accuracy improved from 0.25397 to 0.28295, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 100s 111ms/step - accuracy: 0.2541 - loss: 2.1406 - val_accuracy: 0.2829 - val_loss: 1.9786 - learning_rate: 0.0100
# Epoch 4/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.2902 - loss: 1.9819
# Epoch 4: val_accuracy improved from 0.28295 to 0.31569, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 99s 111ms/step - accuracy: 0.2903 - loss: 1.9819 - val_accuracy: 0.3157 - val_loss: 1.8979 - learning_rate: 0.0100
# Epoch 5/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3278 - loss: 1.8533
# Epoch 5: val_accuracy improved from 0.31569 to 0.36180, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 99s 110ms/step - accuracy: 0.3279 - loss: 1.8533 - val_accuracy: 0.3618 - val_loss: 1.7280 - learning_rate: 0.0100
# Epoch 6/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3571 - loss: 1.7575
# Epoch 6: val_accuracy improved from 0.36180 to 0.41864, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 99s 110ms/step - accuracy: 0.3571 - loss: 1.7575 - val_accuracy: 0.4186 - val_loss: 1.6239 - learning_rate: 0.0100
# Epoch 7/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3706 - loss: 1.7032
# Epoch 7: val_accuracy did not improve from 0.41864
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 112ms/step - accuracy: 0.3706 - loss: 1.7031 - val_accuracy: 0.2561 - val_loss: 2.0375 - learning_rate: 0.0100
# Epoch 8/10
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3884 - loss: 1.6522
# Epoch 8: val_accuracy did not improve from 0.41864
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.3884 - loss: 1.6522 - val_accuracy: 0.3448 - val_loss: 1.8320 - learning_rate: 0.0100
# Epoch 9/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3980 - loss: 1.6186
# Epoch 9: val_accuracy did not improve from 0.41864
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.3980 - loss: 1.6186 - val_accuracy: 0.4104 - val_loss: 1.5964 - learning_rate: 0.0100
# Epoch 10/10
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3985 - loss: 1.5987
# Epoch 10: val_accuracy did not improve from 0.41864
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 100s 112ms/step - accuracy: 0.3985 - loss: 1.5987 - val_accuracy: 0.4058 - val_loss: 1.6474 - learning_rate: 0.0100
# Restoring model weights from the end of the best epoch: 9.
# Epoch 10/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3934 - loss: 1.6119
# Epoch 10: val_accuracy did not improve from 0.41864
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 114ms/step - accuracy: 0.3935 - loss: 1.6118 - val_accuracy: 0.4185 - val_loss: 1.5674 - learning_rate: 0.0100
# Epoch 11/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4180 - loss: 1.5678
# Epoch 11: val_accuracy improved from 0.41864 to 0.44790, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 112ms/step - accuracy: 0.4180 - loss: 1.5677 - val_accuracy: 0.4479 - val_loss: 1.4751 - learning_rate: 0.0090
# Epoch 12/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.4233 - loss: 1.5430
# Epoch 12: val_accuracy did not improve from 0.44790
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 99s 110ms/step - accuracy: 0.4233 - loss: 1.5430 - val_accuracy: 0.4401 - val_loss: 1.4819 - learning_rate: 0.0082
# Epoch 13/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4243 - loss: 1.5349
# Epoch 13: val_accuracy improved from 0.44790 to 0.46921, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 112ms/step - accuracy: 0.4243 - loss: 1.5348 - val_accuracy: 0.4692 - val_loss: 1.4205 - learning_rate: 0.0074
# Epoch 14/35
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4295 - loss: 1.5105
# Epoch 14: val_accuracy improved from 0.46921 to 0.48050, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 113ms/step - accuracy: 0.4296 - loss: 1.5105 - val_accuracy: 0.4805 - val_loss: 1.3963 - learning_rate: 0.0067
# Epoch 15/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4367 - loss: 1.4964
# Epoch 15: val_accuracy did not improve from 0.48050
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 114ms/step - accuracy: 0.4367 - loss: 1.4964 - val_accuracy: 0.4709 - val_loss: 1.4030 - learning_rate: 0.0061
# Epoch 16/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4408 - loss: 1.4845
# Epoch 16: val_accuracy did not improve from 0.48050
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 109s 121ms/step - accuracy: 0.4408 - loss: 1.4845 - val_accuracy: 0.4536 - val_loss: 1.4338 - learning_rate: 0.0055
# Epoch 17/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4462 - loss: 1.4649
# Epoch 17: val_accuracy improved from 0.48050 to 0.48147, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 100s 111ms/step - accuracy: 0.4462 - loss: 1.4649 - val_accuracy: 0.4815 - val_loss: 1.3755 - learning_rate: 0.0050
# Epoch 18/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4487 - loss: 1.4594
# Epoch 18: val_accuracy improved from 0.48147 to 0.48161, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 100s 111ms/step - accuracy: 0.4487 - loss: 1.4594 - val_accuracy: 0.4816 - val_loss: 1.3835 - learning_rate: 0.0045
# Epoch 19/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4585 - loss: 1.4389
# Epoch 19: val_accuracy improved from 0.48161 to 0.48328, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 112ms/step - accuracy: 0.4585 - loss: 1.4389 - val_accuracy: 0.4833 - val_loss: 1.3774 - learning_rate: 0.0041
# Epoch 20/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4550 - loss: 1.4390
# Epoch 20: val_accuracy improved from 0.48328 to 0.48969, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 113ms/step - accuracy: 0.4550 - loss: 1.4390 - val_accuracy: 0.4897 - val_loss: 1.3429 - learning_rate: 0.0037
# Epoch 21/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4646 - loss: 1.4249
# Epoch 21: val_accuracy improved from 0.48969 to 0.49596, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 103s 115ms/step - accuracy: 0.4646 - loss: 1.4249 - val_accuracy: 0.4960 - val_loss: 1.3246 - learning_rate: 0.0033
# Epoch 22/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4655 - loss: 1.4188
# Epoch 22: val_accuracy did not improve from 0.49596
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 116ms/step - accuracy: 0.4655 - loss: 1.4187 - val_accuracy: 0.4875 - val_loss: 1.3739 - learning_rate: 0.0030
# Epoch 23/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4709 - loss: 1.4016
# Epoch 23: val_accuracy improved from 0.49596 to 0.50446, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 116ms/step - accuracy: 0.4709 - loss: 1.4016 - val_accuracy: 0.5045 - val_loss: 1.3130 - learning_rate: 0.0027
# Epoch 24/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4691 - loss: 1.3974
# Epoch 24: val_accuracy did not improve from 0.50446
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 105s 117ms/step - accuracy: 0.4691 - loss: 1.3974 - val_accuracy: 0.5022 - val_loss: 1.3027 - learning_rate: 0.0025
# Epoch 25/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4762 - loss: 1.3867
# Epoch 25: val_accuracy did not improve from 0.50446
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 116ms/step - accuracy: 0.4763 - loss: 1.3867 - val_accuracy: 0.5022 - val_loss: 1.3091 - learning_rate: 0.0022
# Epoch 26/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4761 - loss: 1.3831
# Epoch 26: val_accuracy did not improve from 0.50446
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 115ms/step - accuracy: 0.4761 - loss: 1.3831 - val_accuracy: 0.4908 - val_loss: 1.3444 - learning_rate: 0.0020
# Epoch 27/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4822 - loss: 1.3775
# Epoch 27: val_accuracy did not improve from 0.50446
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 112ms/step - accuracy: 0.4822 - loss: 1.3774 - val_accuracy: 0.5003 - val_loss: 1.3192 - learning_rate: 0.0018
# Epoch 28/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4772 - loss: 1.3743
# Epoch 28: val_accuracy did not improve from 0.50446
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 134s 149ms/step - accuracy: 0.4773 - loss: 1.3743 - val_accuracy: 0.5029 - val_loss: 1.2954 - learning_rate: 0.0017
# Epoch 29/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4818 - loss: 1.3648
# Epoch 29: val_accuracy did not improve from 0.50446
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.4818 - loss: 1.3648 - val_accuracy: 0.4975 - val_loss: 1.3142 - learning_rate: 0.0015
# Epoch 30/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.4846 - loss: 1.3582
# Epoch 30: val_accuracy improved from 0.50446 to 0.50975, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.4846 - loss: 1.3582 - val_accuracy: 0.5098 - val_loss: 1.2816 - learning_rate: 0.0014
# Epoch 31/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4904 - loss: 1.3500
# Epoch 31: val_accuracy did not improve from 0.50975
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 101s 113ms/step - accuracy: 0.4904 - loss: 1.3500 - val_accuracy: 0.5091 - val_loss: 1.2884 - learning_rate: 0.0012
# Epoch 32/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4914 - loss: 1.3507
# Epoch 32: val_accuracy improved from 0.50975 to 0.51379, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 113ms/step - accuracy: 0.4914 - loss: 1.3507 - val_accuracy: 0.5138 - val_loss: 1.2683 - learning_rate: 0.0011
# Epoch 33/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4913 - loss: 1.3463
# Epoch 33: val_accuracy did not improve from 0.51379
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 113ms/step - accuracy: 0.4913 - loss: 1.3463 - val_accuracy: 0.5038 - val_loss: 1.2932 - learning_rate: 0.0010
# Epoch 34/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4930 - loss: 1.3395
# Epoch 34: val_accuracy improved from 0.51379 to 0.51421, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 104s 115ms/step - accuracy: 0.4930 - loss: 1.3395 - val_accuracy: 0.5142 - val_loss: 1.2745 - learning_rate: 9.0718e-04
# Epoch 35/35
# 897/898 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4904 - loss: 1.3447
# Epoch 35: val_accuracy improved from 0.51421 to 0.51686, saving model to ./model.keras
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 102s 113ms/step - accuracy: 0.4904 - loss: 1.3446 - val_accuracy: 0.5169 - val_loss: 1.2653 - learning_rate: 8.2085e-04
# Restoring model weights from the end of the best epoch: 35.

# %%
# Comparison Function
def compare_historys(original_history, new_history, initial_epochs=10):
    acc = original_history.history["accuracy"]
    loss = original_history.history["loss"]
    val_acc = original_history.history["val_accuracy"]
    val_loss = original_history.history["val_loss"]

    total_acc = acc + new_history.history["accuracy"]
    total_loss = loss + new_history.history["loss"]
    total_val_acc = val_acc + new_history.history["val_accuracy"]
    total_val_loss = val_loss + new_history.history["val_loss"]

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(total_acc, label='Training Accuracy')
    plt.plot(total_val_acc, label='Validation Accuracy')
    plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(total_loss, label='Training Loss')
    plt.plot(total_val_loss, label='Validation Loss')
    plt.plot([initial_epochs-1, initial_epochs-1], plt.ylim(), label='Start Fine Tuning')
    plt.legend(loc='upper right');
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
model_1.predict(testing_data)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step
# array([[0.20545146, 0.01499176, 0.32936966, ..., 0.12176564, 0.19856526,
#         0.07817142],
#        [0.14752784, 0.00555411, 0.17286675, ..., 0.18516755, 0.3967102 ,
#         0.02476017],
#        [0.28917265, 0.03488296, 0.08781228, ..., 0.24692614, 0.33204794,
#         0.00326317],
#        ...,
#        [0.0192038 , 0.00104549, 0.14294662, ..., 0.00249135, 0.00316959,
#         0.5689226 ],
#        [0.06082296, 0.00638565, 0.25409034, ..., 0.09333109, 0.07694516,
#         0.4909147 ],
#        [0.19683813, 0.03087414, 0.10163438, ..., 0.23244217, 0.26966465,
#         0.00816089]], dtype=float32)
